# %% [markdown]
# ### QUESTION ; use pandas to clean and preprocess a messy dataset, decument the steps taken during the cleaning proccess

# %% [markdown]
# ### 1. importing pandas library

# %%
# import library
import pandas as pd

# %% [markdown]
# ### 2. uploading data set

# %%
# importing dataset
ambassador = pd.read_excel(r"C:\Users\ewoo\Desktop\3 STAR RES. COMMUNITY.xlsx")

# %% [markdown]
# ### 3. displaying dataset

# %%
# viewing dataset
ambassador
# Out:
#     S/N             NAMES  HOUSE NO.  TAKE UP CONTRIBUTION  \
# 0     1      Auwal Haruna         19                  5000
# 1     2      Musa Musbahu         17                  3000
# 2     3  Ja'afar Ja'afar_         18                  6000
# 3     4     Hassan %%Musa         15                  7000
# 4     5      sale Kumbula         16                  6000
# 5     6      Yakubu Chamo         20                  4000
# 6     7      Inusa Zakari          1                  7000
# 7     8     Yahaya Haruna          9                 20000
# 8     9      /Nura Okocha          4                  4000
# 9    10      Yarima Chamo          2                  3000
# 10   11     Bala Yanleman          3                  7000
# 11   12      Kamal Muktar          8                 10000
# 12   13       Fa'izu Bala          5                 10000
# 13   14       Umar Khalid          6                  4000
# 14   15       Auwal Jamil          7                 25000
# ...

# %% [markdown]
# ### 4. cleaning dataset column by column

# %%
# cleaning names column
ambassador
# Out:
#     S/N             NAMES  HOUSE NO.  TAKE UP CONTRIBUTION  \
# 0     1      Auwal Haruna         19                  5000
# 1     2      Musa Musbahu         17                  3000
# 2     3  Ja'afar Ja'afar_         18                  6000
# 3     4     Hassan %%Musa         15                  7000
# 4     5      sale Kumbula         16                  6000
# 5     6      Yakubu Chamo         20                  4000
# 6     7      Inusa Zakari          1                  7000
# 7     8     Yahaya Haruna          9                 20000
# 8     9      /Nura Okocha          4                  4000
# 9    10      Yarima Chamo          2                  3000
# 10   11     Bala Yanleman          3                  7000
# 11   12      Kamal Muktar          8                 10000
# 12   13       Fa'izu Bala          5                 10000
# 13   14       Umar Khalid          6                  4000
# 14   15       Auwal Jamil          7                 25000
# ...

# %%
# removing unwanted character
ambassador["NAMES"] = ambassador["NAMES"].str.strip("_%%/")

# %%
ambassador
# Out:
#     S/N            NAMES  HOUSE NO.  TAKE UP CONTRIBUTION  \
# 0     1     Auwal Haruna         19                  5000
# 1     2     Musa Musbahu         17                  3000
# 2     3  Ja'afar Ja'afar         18                  6000
# 3     4    Hassan %%Musa         15                  7000
# 4     5     sale Kumbula         16                  6000
# 5     6     Yakubu Chamo         20                  4000
# 6     7     Inusa Zakari          1                  7000
# 7     8    Yahaya Haruna          9                 20000
# 8     9      Nura Okocha          4                  4000
# 9    10     Yarima Chamo          2                  3000
# 10   11    Bala Yanleman          3                  7000
# 11   12     Kamal Muktar          8                 10000
# 12   13      Fa'izu Bala          5                 10000
# 13   14      Umar Khalid          6                  4000
# 14   15      Auwal Jamil          7                 25000
# ...

# %%
# repace unwanted character
ambassador["NAMES"] = ambassador["NAMES"].str.replace("Hassan %%Musa", "Hassan Musa")

# %%
# displaying dataset to view changes
ambassador
# Out:
#     S/N            NAMES  HOUSE NO.  TAKE UP CONTRIBUTION  \
# 0     1     Auwal Haruna         19                  5000
# 1     2     Musa Musbahu         17                  3000
# 2     3  Ja'afar Ja'afar         18                  6000
# 3     4      Hassan Musa         15                  7000
# 4     5     sale Kumbula         16                  6000
# 5     6     Yakubu Chamo         20                  4000
# 6     7     Inusa Zakari          1                  7000
# 7     8    Yahaya Haruna          9                 20000
# 8     9      Nura Okocha          4                  4000
# 9    10     Yarima Chamo          2                  3000
# 10   11    Bala Yanleman          3                  7000
# 11   12     Kamal Muktar          8                 10000
# 12   13      Fa'izu Bala          5                 10000
# 13   14      Umar Khalid          6                  4000
# 14   15      Auwal Jamil          7                 25000
# ...

# %%
# removing duplicate
ambassador = ambassador.drop_duplicates()

# %%
ambassador
# Out:
#     S/N            NAMES  HOUSE NO.  TAKE UP CONTRIBUTION  \
# 0     1     Auwal Haruna         19                  5000
# 1     2     Musa Musbahu         17                  3000
# 2     3  Ja'afar Ja'afar         18                  6000
# 3     4      Hassan Musa         15                  7000
# 4     5     sale Kumbula         16                  6000
# 5     6     Yakubu Chamo         20                  4000
# 6     7     Inusa Zakari          1                  7000
# 7     8    Yahaya Haruna          9                 20000
# 8     9      Nura Okocha          4                  4000
# 9    10     Yarima Chamo          2                  3000
# 10   11    Bala Yanleman          3                  7000
# 11   12     Kamal Muktar          8                 10000
# 12   13      Fa'izu Bala          5                 10000
# 13   14      Umar Khalid          6                  4000
# 14   15      Auwal Jamil          7                 25000
# ...

# %%
# removing the remark column
ambassador = ambassador.drop(columns = "REMARK")

# %%
ambassador
# Out:
#     S/N            NAMES  HOUSE NO.  TAKE UP CONTRIBUTION  \
# 0     1     Auwal Haruna         19                  5000
# 1     2     Musa Musbahu         17                  3000
# 2     3  Ja'afar Ja'afar         18                  6000
# 3     4      Hassan Musa         15                  7000
# 4     5     sale Kumbula         16                  6000
# 5     6     Yakubu Chamo         20                  4000
# 6     7     Inusa Zakari          1                  7000
# 7     8    Yahaya Haruna          9                 20000
# 8     9      Nura Okocha          4                  4000
# 9    10     Yarima Chamo          2                  3000
# 10   11    Bala Yanleman          3                  7000
# 11   12     Kamal Muktar          8                 10000
# 12   13      Fa'izu Bala          5                 10000
# 13   14      Umar Khalid          6                  4000
# 14   15      Auwal Jamil          7                 25000
# ...

# %%
# dropping index colunm
ambassador = ambassador.drop(columns = "S/N")

# %% [markdown]
# # displaying cleaned dataset

# %%
# final result
ambassador
# Out:
#               NAMES  HOUSE NO.  TAKE UP CONTRIBUTION  MONTHLY  CONTRIBUTION   \
# 0      Auwal Haruna         19                  5000                    2000
# 1      Musa Musbahu         17                  3000                    8000
# 2   Ja'afar Ja'afar         18                  6000                    2000
# 3       Hassan Musa         15                  7000                    2000
# 4      sale Kumbula         16                  6000                    2000
# 5      Yakubu Chamo         20                  4000                    4000
# 6      Inusa Zakari          1                  7000                    8000
# 7     Yahaya Haruna          9                 20000                   10000
# 8       Nura Okocha          4                  4000                   16000
# 9      Yarima Chamo          2                  3000                    4000
# 10    Bala Yanleman          3                  7000                    2000
# ...
